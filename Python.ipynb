# %% [markdown]
# <a href="https://colab.research.google.com/github/likhitha774/python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X=6
Y=6
print(X+Y)
# Out:
# 12

# %%
X=("Banana")
Y=("4")
print(X,Y)
# Out:
# Banana 4

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %%
X='4'
Y='5'
print(X+Y)
# Out:
# 45

# %%
x=['apple']
y=['banana']
print(x,y)
# Out:
# ['apple'] ['banana']

# %%
l=3
b=2
area=l*b
print(area)
# Out:
# 6

# %%
a=18
b=2
print("eligible",a>b)
# Out:
# eligible True

# %%
a=19
print("eligible for",a>=19)
print("not eligible for",a<19)
# Out:
# eligible for True
# not eligible for False

# %%
a=5
b=8
print('even',a%2==0)
print('odd',b%2==0)
# Out:
# even False
# odd True

# %%
a=int(input("enter the value:"))
result=["even","odd"][a%2]
print("the number is", result)
# Out:
# enter the value:2
# the number is even

# %%
a=int(input())
if(a%4==0 and a%5==0):
    print("fizz,buzz")
elif(a%5==0):
    Print("fizz")
elif(a%4==0):
    print("buzz")
else:
    print("not valid")

# %%
A=int(input())
B=int(input())
print(A+B)
print(A-B)
print(A*B)
print(A/B)

# %%
r=int(input())
circle=2*3.141*r
print(circle)

# %%
a=int(int())
if(a<10):
    print("true")
else:
    print("false")

# %%
a=input()
if(a=="green"):
    print("found")
else:
    print("not found")

# %%
a=(int())
if(a>10):
    print("a is greater than")
elif(a==10):
    print("equal")
else:
    print("less than")

# %%
for i in range(2,11,2):
     print(i)

# %%
fruit=["apple","banana", "grapes"]
for i in fruit:
    print(i)

# %%
a=["banana,apple"]
for i in "banana":
    print(i)

# %%
for i in range(5):
  for j in range(1,6):
    print("*",end=' ')
  print()

# %%
n=int(input())
for i in range (n):
  for j in range (n):
    print("*",end='')
  print()

# %%
a=4
for i in range (1,+1):
    print("*"*i)

# %%
a=5
for i in range (a,a,-1):
    print("*"*i)

# %%
n=5
for i in range (1,n+1):
    print("*"*i)

# %%
a=5
for i in range(a,0-1):
    print(""*(n-i),end="")
    print("*"*(1*i-1))

# %%
for x in range (65,70):
  for y in range (65,x+1):
    print(chr(x),end=" ")
  print()

# %%
a=5
for i in range (a,0,-1):
    print("*"*i)

# %%
for i in range(65,70):
  for j in range(65,i+1):
    print(chr(j),end="")
  print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
n=int(input())
while(i<5):
    print(i)
    i+=1
# Out:
# 2

# %%
i = 0
while(i < 5):
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n=int(input())
for i in range(n):
    print(i)
# Out:
# 3
# 0
# 1
# 2

# %%
for i in range (1,7):
    if (i==4):
      continue
    print(i)
# Out:
# 1
# 2
# 3
# 5
# 6

# %%
for i in range (1,7):
    if (i==4):
      break
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range (1,7):
    if (i==4):
      pass
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a="string"
print(type(a))
# Out:
# <class 'str'>

# %%
a=int
print(type(a))
# Out:
# <class 'type'>

# %%
a=['hello']
print(type(a))
# Out:
# <class 'list'>

# %%
a=float(input())
print(type(a))
print(a)
# Out:
# 2
# <class 'float'>
# 2.0

# %%
a=('world',2,5.5)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=2
b=3
print('true',a>b)
print('flase',a<b)
# Out:
# true False
# flase True
